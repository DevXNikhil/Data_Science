# %%
# Working with files
# cd = change directory

# %%
# Example - 1
f = open("test.txt",'w') # New file created

# %%
pwd # Present working directory
# Out:
# 'C:\\Users\\HP 01\\PYTHON\\WorkingWithFiles'

# %%
ls # list
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8217-E122
#
#  Directory of C:\Users\HP 01\PYTHON\WorkingWithFiles
#
#
#  Directory of C:\Users\HP 01\PYTHON\WorkingWithFiles
# File Not Found

# %%
f.write("This is my first file")
# Out:
# 21

# %%
f.close()

# %%
# Example - 2
f = open("test.txt",'w') # Opening a file in write mode

# %%
f.write("Today is 9th of january")
# Out:
# 23

# %%
f.close() # closing the file

# %%
# Example - 3
f = open("test.txt",'a') # Opening a file append mode

# %%
f.write(",and this a a 21st day of becomining a data scientist")
# Out:
# 53

# %%
f.close()

# %%
# Example - 4
f = open("test.txt",'r') # opening a file in read mode

# %%
f.read() # reading all data using in-built function -> read()
# Out:
# 'Today is 9th of january,and this a a 21st day of becomining a data scientist'

# %%
# Example - 5 line by line read
f.seek(0) # setting pointer at 0th position for line by line reading
# Out:
# 0

# %%
f.readline() # reading line by line
# Out:
# 'Today is 9th of january,and this a a 21st day of becomining a data scientist'

# %%
f.readline() # without setting a pointer it will not give any data
# Out:
# ''

# %%
f.seek(12) # setting a pointer at specific position
# Out:
# 12

# %%
f.readline() # it will only read the data from 12 position
# Out:
# ' of january,and this a a 21st day of becomining a data scientist'

# %%
# Example - 6
f1 = open("test.txt",'r') # read mode

# %%
for i in f1: # Reading data using for loop
    print(i)
# Out:
# Today is 9th of january,and this a a 21st day of becomining a data scientist

# %%
# Example - 7 
# Finding the size of a file
import os

# %%
os.path.getsize("test.txt") # Finding the size of a file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 os.path.getsize("test.txt") # Finding the size of a file
#
# File ~\miniconda3\Lib\genericpath.py:86, in getsize(filename)
#      84 def getsize(filename):
#      85     """Return the size of a file, reported by os.stat()."""
# ---> 86     return os.stat(filename).st_size
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'test.txt'

# %%
# deleting a file
os.remove("test.txt") # file is deleted now
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # deleting a file
# ----> 2 os.remove("test.txt") # file is deleted now
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'test.txt'

# %%
# Example - 8
f = open("test1.txt",'w')

# %%
f.write("It was a quiet evening, and the sky slowly changed its color from bright blue to soft orange. People were returning home after a long day, some tired, some thinking about tomorrow. A cool breeze moved through the streets, making the trees sway gently. Everything felt calm, simple, and peaceful, as if the day was taking a deep breath before coming to an end.")
# Out:
# 359

# %%
f.close()

# %%
# Example - 9 Rename

# %%
os.rename("test1.txt","new.txt") # file renamed -> new.txt

# %%
import shutil # importing it to copy the file into another file

# %%
shutil.copy("new.txt","copy_new.txt") # Copying the contents of new.txt into copy_new.txt
# Out:
# 'copy_new.txt'

# %%
# Example - 10 
# opening file using [with open]

# %%
with open("new.txt","r") as f:
    print(f.read())
# Out:
# It was a quiet evening, and the sky slowly changed its color from bright blue to soft orange. People were returning home after a long day, some tired, some thinking about tomorrow. A cool breeze moved through the streets, making the trees sway gently. Everything felt calm, simple, and peaceful, as if the day was taking a deep breath before coming to an end.
